# %% [markdown]
# <a href="https://colab.research.google.com/github/raaga102005/python-automation-scripts/blob/main/webscraping_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install if needed
# !pip install requests beautifulsoup4

import requests
from bs4 import BeautifulSoup
import pandas as pd

# Fetch the practice website
url = "https://books.toscrape.com"
response = requests.get(url)
print("Status code:", response.status_code)

# Parse the HTML
soup = BeautifulSoup(response.content, "html.parser")

# Find all books
books = soup.find_all("article", class_="product_pod")
print(f"Found {len(books)} books on this page")

# Extract data
data = []
for book in books:
    title = book.find("h3").find("a")["title"]
    price = book.find("p", class_="price_color").text.strip()
    data.append({"Title": title, "Price": price})

# Create dataframe
df = pd.DataFrame(data)
print(df.head())

# Save to CSV
df.to_csv("scraped_books.csv", index=False)
print("Saved to scraped_books.csv")
# Out:
# Status code: 200
# Found 20 books on this page
#                                    Title   Price
# 0                   A Light in the Attic  £51.77
# 1                     Tipping the Velvet  £53.74
# 2                             Soumission  £50.10
# 3                          Sharp Objects  £47.82
# 4  Sapiens: A Brief History of Humankind  £54.23
# Saved to scraped_books.csv
